# %%
import matplotlib.pyplot as plt

# %%
Number_of_Blocks  =   [4, 8, 12, 16, 20]
K3 = [25,    26.2,   26.5,   26.6,   26.2]
K5 = [25.25, 26.28,   26.45,   26.77,  26.3]
K7 = [25.36, 26.40,   26.49,   26.81,  26.5]

# Plot lists and show them
#plt.plot(x,K3, 'go-')
plt.plot(Number_of_Blocks,K3, 'ro-') #color marker line (color = red,  line )
plt.plot(Number_of_Blocks,K5, 'gs-')
plt.plot(Number_of_Blocks,K7, 'bp-')
plt.title('Ablation Study of Our SENext Model')
plt.xlabel('Network Depth (Number of Layers)')
plt.ylabel('PSNR (dB) SET5 SCALE FACTOR 8X')
plt.legend(['Single Path Network', 'Two Path Network', 'Multi-Path Network'], loc=4)
plt.grid()
plt.show()
